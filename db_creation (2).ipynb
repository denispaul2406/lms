# %%
import sqlite3
import csv

# Connect to SQLite database
conn = sqlite3.connect('library11.db')
cursor = conn.cursor()

# Function to insert data into Books table
def insert_books_data(row):
    cursor.execute('''
            INSERT INTO Books (BK_ID, BK_NAME, AUTHOR_NAME, Edition, Date_Year, Publisher, Place, ISBN, Price, Pages, Category, Department, Subject) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    ''', (row['Access_No'], row['Title'], row['Authors'], row['Edition'], row['Date_Year'],
          row['Publisher'], row['Place'], row['ISBN'], row['Price'], row['Pages'],row['Category'],row['Department'],row['Subject']))

# Function to insert data into BookDetails table
def insert_book_details_data(row):
    cursor.execute('''
        INSERT INTO BookDetails (Asset_Code, Call_No, BK_ID)
        VALUES (?, ?, ?)
    ''', (row['Asset_Code'], row['Call_No'], row['Access_No']))

# Function to insert data into BookCategories table
# def insert_book_categories_data(row):
#     cursor.execute('''
#         INSERT INTO BookCategories (Category)
#         VALUES (?)
#     ''', (row['Category'],))


# Function to insert data into BookInventory table
def insert_book_inventory_data(row):
    cursor.execute('''
        INSERT INTO BookInventory (BK_ID, Number_of_Copies)
        VALUES (?, ?)
    ''', (row['Access_No'], row['copies']))

# Function to insert data into Departments table
# def insert_departments_data(row):
#     cursor.execute('''
#         INSERT INTO Departments (Department)
#         VALUES (?)
#     ''', (row['Department'],))

# Function to insert data into Subjects table
# def insert_subjects_data(row):
#     cursor.execute('''
#         INSERT INTO Subjects (Subject)
#         VALUES (?)
#     ''', (row['Subject'],))

# Function to insert data into Transactions table
def insert_transactions_data(row):
    cursor.execute('''
        INSERT INTO Transactions (BK_ID, Bill_Date, Vendor)
        VALUES (?, ?, ?)
    ''', (row['Access_No'], row['Bill_Date'], row['Vendor']))

# Function to handle the CSV data insertion into respective tables
def process_csv_data():
    with open('C:/Users/Hunny/Downloads/updated_file.csv', newline='', encoding='latin-1') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            # Insert data into respective tables
            insert_books_data(row)
            insert_book_details_data(row)
            # insert_book_categories_data(row)
            insert_book_inventory_data(row)
            # insert_departments_data(row)
            # insert_subjects_data(row)
            insert_transactions_data(row)
            # Add other table insertions if necessary

    conn.commit()
    print("Data inserted successfully.")

# Call the function to insert data from CSV into respective tables
process_csv_data()

# Close connection
conn.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\manju\OneDrive\Desktop\BSC_3rdSem\DBMS2\Library_management_system\lms_8\db_creation (2).ipynb Cell 1 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/manju/OneDrive/Desktop/BSC_3rdSem/DBMS2/Library_management_system/lms_8/db_creation%20%282%29.ipynb#W0sZmlsZQ%3D%3D?line=73'>74</a>     print("Data inserted successfully.")
#      <a href='vscode-notebook-cell:/c%3A/Users/manju/OneDrive/Desktop/BSC_3rdSem/DBMS2/Library_management_system/lms_8/db_creation%20%282%29.ipynb#W0sZmlsZQ%3D%3D?line=75'>76</a> # Call the function to insert data from CSV into respective tables
# ---> <a href='vscode-notebook-cell:/c%3A/Users/manju/OneDrive/Desktop/BSC_3rdSem/DBMS2/Library_management_system/lms_8/db_creation%20%282%29.ipynb#W0sZmlsZQ%3D%3D?line=76'>77</a> process_csv_data()
#      <a href='vscode-notebook-cell:/c%3A/Users/manju/OneDrive/Desktop/BSC_3rdSem/DBMS2/Library_management_system/lms_8/db_creation%20%282%29.ipynb#W0sZmlsZQ%3D%3D?line=78'>79</a> # Close connection
#      <a href='vscode-notebook-cell:/c%3A/Users/manju/OneDrive/Desktop/BSC_3rdSem/DBMS2/Library_management_system/lms_8/db_creation%20%282%29.ipynb#W0sZmlsZQ%3D%3D?line=79'>80</a> conn.close()
#
# c:\Users\manju\OneDrive\Desktop\BSC_3rdSem\DBMS2\Library_management_system\lms_8\db_creation (2).ipynb Cell 1 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/manju/OneDrive/Desktop/BSC_3rdSem/DBMS2/Library_management_system/lms_8/db_creation%20%282%29.ipynb#W0sZmlsZQ%3D%3D?line=58'>59</a> def process_csv_data():
# ---> <a href='vscode-notebook-cell:/c%3A/Users/manju/OneDrive/Desktop/BSC_3rdSem/DBMS2/Library_management_system/lms_8/db_creation%20%282%29.ipynb#W0sZmlsZQ%3D%3D?line=59'>60</a>     with open('C:/Users/Hunny/Downloads/updated_file.csv', newline='', encoding='latin-1') as csvfile:
#      <a href='vscode-notebook-cell:/c%3A/Users/manju/OneDrive/Desktop/BSC_3rdSem/DBMS2/Library_management_system/lms_8/db_creation%20%282%29.ipynb#W0sZmlsZQ%3D%3D?line=60'>61</a>         reader = csv.DictReader(csvfile)
#      <a href='vscode-notebook-cell:/c%3A/Users/manju/OneDrive/Desktop/BSC_3rdSem/DBMS2/Library_management_system/lms_8/db_creation%20%282%29.ipynb#W0sZmlsZQ%3D%3D?line=61'>62</a>         for row in reader:
#      <a href='vscode-notebook-cell:/c%3A/Users/manju/OneDrive/Desktop/BSC_3rdSem/DBMS2/Library_management_system/lms_8/db_creation%20%282%29.ipynb#W0sZmlsZQ%3D%3D?line=62'>63</a>             # Insert data into respective tables
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:308, in _modified_open(file, *args, **kwargs)
#     301 if file in {0, 1, 2}:
#     302     raise ValueError(
#     303         f"IPython won't let you open fd={file} by default "
#     304         "as it is likely to crash IPython. If you know what you are doing, "
#     305         "you can use builtins' open."
#     306     )
# --> 308 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Hunny/Downloads/updated_file.csv'

# %%
a =cursor.execute('PRAGMA table_info(BookDetails);')
print(a)
# Out:
# <sqlite3.Cursor object at 0x000001E15558FA40>

# %%
import sqlite3

# Connect to SQLite database (create if not exists)
conn = sqlite3.connect('library8.db')
cursor = conn.cursor()

# Drop existing tables if they exist
cursor.execute("DROP TABLE IF EXISTS BookInventory")
cursor.execute("DROP TABLE IF EXISTS Transactions")
cursor.execute("DROP TABLE IF EXISTS Subjects")
cursor.execute("DROP TABLE IF EXISTS Departments")
cursor.execute("DROP TABLE IF EXISTS BookCategories")
cursor.execute("DROP TABLE IF EXISTS BookDetails")
cursor.execute("DROP TABLE IF EXISTS Books")

# Create Books table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS Books (
        BK_ID TEXT PRIMARY KEY NOT NULL,
        BK_NAME TEXT,
        AUTHOR_NAME TEXT,
        Edition TEXT,
        Date_Year TEXT,
        Publisher TEXT,
        Place TEXT,
        ISBN TEXT,
        Price TEXT,
        Pages TEXT,
        Category_ID INTEGER,
        Department_ID INTEGER,
        Subject_ID INTEGER,
        FOREIGN KEY (Category_ID) REFERENCES BookCategories(Category_ID),
        FOREIGN KEY (Department_ID) REFERENCES Departments(Department_ID),
        FOREIGN KEY (Subject_ID) REFERENCES Subjects(Subject_ID)
    )
''')

# Create BookInventory table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS BookInventory (
        BK_ID TEXT PRIMARY KEY NOT NULL,
        Number_of_Copies INTEGER,
        FOREIGN KEY (BK_ID) REFERENCES Books(BK_ID)
    )
''')

# Create BookDetails table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS BookDetails (
        Asset_Code TEXT,
        Call_No TEXT,
        BK_ID TEXT NOT NULL,
        BK_STATUS TEXT,
        FOREIGN KEY (BK_ID) REFERENCES Books(BK_ID)
    )
''')

# Create BookCategories table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS BookCategories (
        Category_ID INTEGER PRIMARY KEY AUTOINCREMENT,
        Category TEXT
    )
''')

# Create Departments table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS Departments (
        Department_ID INTEGER PRIMARY KEY AUTOINCREMENT,
        Department TEXT
    )
''')

# Create Subjects table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS Subjects (
        Subject_ID INTEGER PRIMARY KEY AUTOINCREMENT,
        Subject TEXT
    )
''')

# Create Transactions table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS Transactions (
        Transaction_ID INTEGER PRIMARY KEY AUTOINCREMENT,
        BK_ID TEXT,
        CARD_ID TEXT,
        Bill_Date TEXT,
        Vendor TEXT,
        FOREIGN KEY (BK_ID) REFERENCES Books(BK_ID)
    )
''')

# Create VIEW Library
cursor.execute('''
    CREATE VIEW IF NOT EXISTS Library AS
    SELECT
        Books.BK_NAME AS book_name,
        Books.BK_ID AS book_id,
        Books.AUTHOR_NAME AS author_name,
        BookDetails.BK_STATUS AS book_status,
        Transactions.CARD_ID AS card_id,
        BookCategories.Category_ID AS category_id,
        BookDetails.Asset_Code AS asset_code,
        Departments.Department_ID AS department_id,
        Subjects.Subject_ID AS subject_id,
        Books.Edition AS edition,
        Books.Date_Year AS date_year,
        BookDetails.Call_No AS call_no, 
        Books.Publisher AS publisher,
        Books.Place AS place,
        Books.ISBN AS isbn,
        Books.Price AS price,
        Transactions.Bill_Date AS bill_date,
        Transactions.Vendor AS vendor,
        Books.Pages AS pages,
        BookInventory.Number_of_Copies AS num_copies
    FROM
        Books
    LEFT JOIN BookCategories ON Books.Category_ID = BookCategories.Category_ID
    LEFT JOIN BookDetails ON Books.BK_ID = BookDetails.BK_ID
    LEFT JOIN Transactions ON Books.BK_ID = Transactions.BK_ID
    LEFT JOIN Departments ON Books.Department_ID = Departments.Department_ID
    LEFT JOIN Subjects ON Books.Subject_ID = Subjects.Subject_ID
    LEFT JOIN BookInventory ON Books.BK_ID = BookInventory.BK_ID
''')

print("Tables created successfully.")
conn.commit()
conn.close()
# Out:
# Tables created successfully.

# %%
import sqlite3

# Connect to SQLite database (create if not exists)
conn = sqlite3.connect('library11.db')
cursor = conn.cursor()

# Drop existing tables if they exist
cursor.execute("DROP TABLE IF EXISTS BookInventory")
cursor.execute("DROP TABLE IF EXISTS Transactions")
cursor.execute("DROP TABLE IF EXISTS BookDetails")
cursor.execute("DROP TABLE IF EXISTS Books")

# Create Books table with merged fields for category, department, and subject
cursor.execute('''
    CREATE TABLE IF NOT EXISTS Books (
        BK_ID TEXT PRIMARY KEY NOT NULL,
        BK_NAME TEXT,
        AUTHOR_NAME TEXT,
        Edition TEXT,
        Date_Year TEXT,
        Publisher TEXT,
        Place TEXT,
        ISBN TEXT,
        Price TEXT,
        Pages TEXT,
        Category TEXT,
        Department TEXT,
        Subject TEXT
    )
''')

# Create BookInventory table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS BookInventory (
        BK_ID TEXT PRIMARY KEY NOT NULL,
        Number_of_Copies INTEGER,
        FOREIGN KEY (BK_ID) REFERENCES Books(BK_ID)
    )
''')

# Create BookDetails table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS BookDetails (
        Asset_Code TEXT,
        Call_No TEXT,
        BK_ID TEXT NOT NULL,
        BK_STATUS TEXT,
        FOREIGN KEY (BK_ID) REFERENCES Books(BK_ID)
    )
''')

# Create Transactions table
# cursor.execute('''
#     CREATE TABLE IF NOT EXISTS Transactions (
#         Transaction_ID INTEGER PRIMARY KEY AUTOINCREMENT,
#         BK_ID TEXT,
#         CARD_ID TEXT,
#         Bill_Date TEXT,
#         Vendor TEXT,
#         FOREIGN KEY (BK_ID) REFERENCES Books(BK_ID)
#     )
# ''')
cursor.execute('''
    CREATE TABLE IF NOT EXISTS Transactions (
        Transaction_ID INTEGER PRIMARY KEY AUTOINCREMENT,
        BK_ID TEXT,
        CARD_ID TEXT,
        Bill_Date TEXT,
        Borrow_Date TEXT, -- New column to store the borrowing date
        Return_Date TEXT, -- New column to store the return date
        Vendor TEXT,
        Fine REAL DEFAULT 0, -- New column for storing fine amount, initialized to 0
        FOREIGN KEY (BK_ID) REFERENCES Books(BK_ID)
    )
''')

# Create VIEW Library
cursor.execute('''
    CREATE VIEW IF NOT EXISTS Library AS
    SELECT
        Books.BK_NAME AS book_name,
        Books.BK_ID AS book_id,
        Books.AUTHOR_NAME AS author_name,
        BookDetails.BK_STATUS AS book_status,
        Transactions.CARD_ID AS card_id,
        Books.Category AS category,
        BookDetails.Asset_Code AS asset_code,
        Books.Department AS department,
        Books.Subject AS subject,
        Books.Edition AS edition,
        Books.Date_Year AS date_year,
        BookDetails.Call_No AS call_no, 
        Books.Publisher AS publisher,
        Books.Place AS place,
        Books.ISBN AS isbn,
        Books.Price AS price,
        Transactions.Bill_Date AS bill_date,
        Transactions.Vendor AS vendor,
        Books.Pages AS pages,
        BookInventory.Number_of_Copies AS num_copies
    FROM
        Books
    LEFT JOIN BookDetails ON Books.BK_ID = BookDetails.BK_ID
    LEFT JOIN Transactions ON Books.BK_ID = Transactions.BK_ID
    LEFT JOIN BookInventory ON Books.BK_ID = BookInventory.BK_ID
''')

print("Tables created successfully.")
conn.commit()
conn.close()
# Out:
# Tables created successfully.

# %%
import sqlite3 as lite
import pandas as pd

# %%
con = lite.connect('library11.db')

# %%
con.execute("UPDATE BookInventory SET Number_of_Copies = 1 WHERE Number_of_Copies IS NULL OR Number_of_Copies NOT BETWEEN 2 AND 100;")

# %%
con.execute("""CREATE TRIGGER prevent_negative_copies
BEFORE UPDATE ON BookInventory
FOR EACH ROW
WHEN NEW.Number_of_Copies < 0
BEGIN
    SELECT RAISE(ABORT, 'Cannot set Number_of_Copies below 0');
END;
""")

# %%
con.commit()

# %%
pd.read_sql("SELECT * FROM BookInventory;",con)
# Out:
#     BK_ID  Number_of_Copies
# 0       1                 9
# 1       9                 2
# 2      11                 2
# 3      13                 8
# 4      21                 2
# ..    ...               ...
# 794  1097                 1
# 795  1098                 1
# 796  1099                 1
# 797  1100                 1
# 798  1101                 1
#
# [799 rows x 2 columns]

# %%
con.close()
